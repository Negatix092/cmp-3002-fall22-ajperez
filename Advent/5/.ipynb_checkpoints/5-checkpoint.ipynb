# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re 
# %matplotlib inline

# %%
f = open("input5.txt", "r")
c = 0
linea = []
for x in f:
    c += 1
    x = x.replace("from 1","from A")
    x = x.replace("from 2","from B")
    x = x.replace("from 3","from C")
    x = x.replace("from 4","from D")
    x = x.replace("from 5","from E")
    x = x.replace("from 6","from F")
    x = x.replace("from 7","from G")
    x = x.replace("from 8","from H")
    x = x.replace("from 9","from I")
    x = x.replace("to 1","to A")
    x = x.replace("to 2","to B")
    x = x.replace("to 3","to C")
    x = x.replace("to 4","to D")
    x = x.replace("to 5","to E")
    x = x.replace("to 6","to F")
    x = x.replace("to 7","to G")
    x = x.replace("to 8","to H")
    x = x.replace("to 9","to I")
    x = x.replace("move", "")
    x = x.replace("from", ",")
    x = x.replace("to", ",")
    x = x.replace(" ","")
    linea.append(x.strip())
c
# Out:
# 502

# %%
linea[-1]
# Out:
# '2,I,B'

# %%
import ctypes
class Stack(object):
    """
    Implementation of the stack data structure
    """

    def __init__(self, n):
        self.l = 0
        self.n = n
        self.stack = self._create_stack(self.n)        
    
    def _create_stack(self, n):
        """
        Creates a new stack of capacity n
        """
        return (n * ctypes.py_object)()
    
    def push(self, item):
        """
        Add new item to the stack
        """
        if self.l == self.n:
            raise ValueError("no more capacity")
        self.stack[self.l] = item
        self.l += 1
        
    def pop(self):
        """
        Remove an element from the stack
        """
        # self.l = 0
        # 0 is equivalent to False
        # any number != 0 is True
        if not self.l:
            raise('stack is empty')
        c = self.stack[self.l-1]
        self.stack[self.l] = ctypes.py_object
        self.l -= 1
        return c
    
    def top(self):
        """
        Show the top element of the stack
        """
        return self.stack[self.l-1]
    
    def full(self):
        """
        Is the stack full?
        """
        return self.l == self.n
        # if self.l == self.n:
        #    return True
        # return False

    def empty(self):
        """
        Is the stack empty?
        """
        return self.l == 0
        #if self.l == 0:
        #    return True
        #return False

    def size(self):
        """
        Return size of the stack
        """
        return self.l

# %%
A = Stack(100)
B = Stack(100)
C = Stack(100)
D = Stack(100)
E = Stack(100)
F = Stack(100)
G = Stack(100)
H = Stack(100)
I = Stack(100)

# %%
A.push("Z")
A.push("J")
A.push("N")
A.push("W")
A.push("P")
A.push("S")

# %%
B.push("G")
B.push("S")
B.push("T")

# %%
C.push("V")
C.push("Q")
C.push("R")
C.push("L")
C.push("H")

# %%
D.push("V")
D.push("S")
D.push("T")
D.push("D")

# %%
E.push("Q")
E.push("Z")
E.push("T")
E.push("D")
E.push("B")
E.push("M")
E.push("J")

# %%
F.push("M")
F.push("W")
F.push("T")
F.push("J")
F.push("D")
F.push("C")
F.push("Z")
F.push("L")

# %%
G.push("L")
G.push("P")
G.push("M")
G.push("W")
G.push("G")
G.push("T")
G.push("J")

# %%
H.push("N")
H.push("G")
H.push("M")
H.push("T")
H.push("B")
H.push("F")
H.push("Q")
H.push("H")

# %%
I.push("R")
I.push("D")
I.push("G")
I.push("C")
I.push("P")
I.push("B")
I.push("Q")
I.push("W")

# %%
actual = []
x = 0

for i in range(0,len(linea)):
    actual = linea[i]
    a2 = re.findall(r'\b\d+\b', actual)
    a3 = re.findall("[a-zA-Z]+", actual)
    
    for i in range(0,int(a2[0])):
        if a3[0]=='A':
            aux = A.pop()
            if a3[1]=='A':
                A.push(aux)
            elif a3[1]=='B':
                B.push(aux)
            elif a3[1]=='C':
                C.push(aux)
            elif a3[1]=='D':
                D.push(aux)
                
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
                
            elif a3[1]=='H':
                H.push(aux)
                
            elif a3[1]=='I':
                I.push(aux)
                
                
        elif a3[0]=='B':
            aux = B.pop()
            if a3[1]=='A':
                A.push(aux)
                
            elif a3[1]=='B':
                B.push(aux)
                
            elif a3[1]=='C':
                C.push(aux)
                
            elif a3[1]=='D':
                D.push(aux)
                
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
                
            elif a3[1]=='H':
                H.push(aux)
                
            elif a3[1]=='I':
                I.push(aux)
                
        
        elif a3[0]=='C':
            aux = C.pop()
            if a3[1]=='A':
                A.push(aux)
                
            elif a3[1]=='B':
                B.push(aux)
                
            elif a3[1]=='C':
                C.push(aux)
                
            elif a3[1]=='D':
                D.push(aux)
                
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
            
            elif a3[1]=='H':
                H.push(aux)
                
            elif a3[1]=='I':
                I.push(aux)
                
        
        elif a3[0]=='D':
            aux = D.pop()
            if a3[1]=='A':
                A.push(aux)
                
            elif a3[1]=='B':
                B.push(aux)
                
            elif a3[1]=='C':
                C.push(aux)
                
            elif a3[1]=='D':
                D.push(aux)
                
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
                
            elif a3[1]=='H':
                H.push(aux)
            
            elif a3[1]=='I':
                I.push(aux)
                
                
        elif a3[0]=='E':
            aux = E.pop()
            if a3[1]=='A':
                A.push(aux)
                
            elif a3[1]=='B':
                B.push(aux)
                
            elif a3[1]=='C':
                C.push(aux)
                
            elif a3[1]=='D':
                D.push(aux)
               
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
                
            elif a3[1]=='H':
                H.push(aux)
                
            elif a3[1]=='I':
                I.push(aux)
                
                
        elif a3[0]=='F':
            aux = F.pop()
            if a3[1]=='A':
                A.push(aux)
                
            elif a3[1]=='B':
                B.push(aux)
               
            elif a3[1]=='C':
                C.push(aux)
                
            elif a3[1]=='D':
                D.push(aux)
                
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
                
            elif a3[1]=='H':
                H.push(aux)
                
            elif a3[1]=='I':
                I.push(aux)
                
                
        elif a3[0]=='G':
            aux = G.pop()
            if a3[1]=='A':
                A.push(aux)
                
            elif a3[1]=='B':
                B.push(aux)
                
            elif a3[1]=='C':
                C.push(aux)
                
            elif a3[1]=='D':
                D.push(aux)
                
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
                
            elif a3[1]=='H':
                H.push(aux)
                
            elif a3[1]=='I':
                I.push(aux)
                
                
        elif a3[0]=='H':
            aux = H.pop()
            if a3[1]=='A':
                A.push(aux)
                
            elif a3[1]=='B':
                B.push(aux)
                
            elif a3[1]=='C':
                C.push(aux)
                
            elif a3[1]=='D':
                D.push(aux)
                
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
                
            elif a3[1]=='H':
                H.push(aux)
                
            elif a3[1]=='I':
                I.push(aux)
               
                
        elif a3[0]=='I':
            aux = I.pop()
            if a3[1]=='A':
                A.push(aux)
                
            elif a3[1]=='B':
                B.push(aux)
                
            elif a3[1]=='C':
                C.push(aux)
                
            elif a3[1]=='D':
                D.push(aux)
                
            elif a3[1]=='E':
                E.push(aux)
                
            elif a3[1]=='F':
                F.push(aux)
                
            elif a3[1]=='G':
                G.push(aux)
                
            elif a3[1]=='H':
                H.push(aux)
                
            elif a3[1]=='I':
                I.push(aux)

# %%
actual
# Out:
# '2,I,B'

# %%
a2
# Out:
# ['2']

# %%
a3
# Out:
# ['I', 'B']

# %%
print(A.top(),B.top(),C.top(),D.top(),E.top(),F.top(),G.top(),H.top(),I.top())
# Out:
# M Q T P G L L D N
